# %%
print("Welcome Child notebook")

# %%
dbutils.widgets.dropdown("environement",
                         defaultValue="DEV",
                         choices=["DEV","TEST","PROD"],
                         label="Environment Type")

# %%
dbutils.notebook.exit("Success")
