# %%
dbutils.notebook.help()

# %%
dbutils.notebook.run("./Child_Notebook01", timeout_seconds=15)

# %%
execution_status = dbutils.notebook.run("./Child_Notebook01", timeout_seconds=15, arguments={
    "environment": "DEV"})
execution_status
