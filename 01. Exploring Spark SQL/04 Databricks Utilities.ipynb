# %%
dbutils.widgets.combobox("top_n_records",
                         defaultValue="1",
                         choices=["1","2","3","4"],
                         label="Top N Records")

# %%
dbutils.widgets.dropdown("Environement",
                         defaultValue="DEV",
                         choices=["DEV","TEST","PROD"],
                         label="Environment")

# %%
dbutils.widgets.multiselect("Technology",
                         defaultValue="5G",
                         choices=["2G","3G","4G"],
                         label="Technology")
